# %%
import os

search_name = "features.txt"
search_dir = "C:\\"  # 전체 C드라이브

found = []
for root, dirs, files in os.walk(search_dir):
    if search_name in files:
        found.append(os.path.join(root, search_name))

if found:
    print("찾은 경로들:")
    for f in found:
        print(f)
else:
    print("❌ features.txt 파일을 못 찾았습니다.")
# Out:
# 찾은 경로들:
# C:\$Recycle.Bin\S-1-5-21-1350883634-2214511677-390552100-1001\$R05UUC6\human_activity\features.txt
# C:\$Recycle.Bin\S-1-5-21-1350883634-2214511677-390552100-1001\$RR73O1V\features.txt
# C:\$Recycle.Bin\S-1-5-21-1350883634-2214511677-390552100-1001\$RYAZS4Q\human_activity\features.txt
# C:\EURON\human_activity\features.txt

# %%
import pandas as pd

def get_human_dataset():
    base_path = r"C:\EURON\human_activity"

    feature_name_df = pd.read_csv(
        base_path + r"\features.txt", sep="\s+",
        header=None, names=['column_index','column_name']
    )
    feature_name = feature_name_df.iloc[:, 1].values.tolist()

    X_train = pd.read_csv(base_path + r"\train\X_train.txt", sep="\s+", header=None)
    X_test  = pd.read_csv(base_path + r"\test\X_test.txt",  sep="\s+", header=None)
    y_train = pd.read_csv(base_path + r"\train\y_train.txt", sep="\s+", header=None)
    y_test  = pd.read_csv(base_path + r"\test\y_test.txt",  sep="\s+", header=None)

    X_train.columns = feature_name
    X_test.columns = feature_name

    return X_train, X_test, y_train, y_test

# %%
from sklearn.ensemble import GradientBoostingClassifier
import time
import warnings
warnings.filterwarnings('ignore')

# %%
X_train, X_test, y_train, y_test = get_human_dataset()

# %%
start_time = time.time()

# %%
gb_clf = GradientBoostingClassifier(random_state=0,n_estimators=10)
gb_clf.fit(X_train, y_train)
gb_pred = gb_clf.predict(X_test)
gb_accuracy = accuracy_score(y_test, gb_pred)

print('GBM 정확도: {0：.4f}'.format(gb_accuracy))
print('GBM 수행 시간: {0：.1f} 초'.format(time.time()-start_time))

# %%
#위의 코드가 20분째 실행시켜도 출력이 안돼요ㅜ
